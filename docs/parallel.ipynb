# %%
from __future__ import annotations

import pickle
import numpy as np
import pandas as pd
from collections.abc import Hashable
from pathlib import Path
from typing import Any

from mxlpy.parallel import Cache, parallelise

# %% [markdown]
# ## Parallelization
#
# `mxlpy` allows easy parallelisation of functions using the `parallel` module.
#
# The API of this is built in a way to allow for easy mapping, saving results and stopping execution of long running functions.
#
# **Sharp edge**: be aware that the usual issues of [multiprocessing on Windows](https://docs.python.org/3.7/library/multiprocessing.html#multiprocessing-programming) apply

# %% [markdown]
# ## Basic API
#
# The most basic call to `parallelise` just requires
#
# 1. A function that consumes an input and returns it's result
# 2. A tuple of `(key, input)`

# %%
def fn(x: int) -> int:
    return x**2


res = parallelise(fn, inputs=[("a", 1), ("b", 2)])

print(dict(res))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Exception: Traceback (most recent call last):
#   File "/home/marvin/git/mxlpy/src/mxlpy/__init__.py", line 42, in <module>
#     import pandas as pd
#   File "/home/marvin/git/mxlpy/.pixi/envs/default/lib/python3.14/site-packages/pandas/__init__.py", line 19, in <module>
#     raise ImportError(
#         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#     )
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.
#
# The above exception was the direct cause of the following exception:
#
# concurrent.interpreters.NotShareableError: object could not be unpickled
#
# The above exception was the direct cause of the following exception:
#
# NotShareableError                         Traceback (most recent call last)
# Cell In[2], line 7
#       2     return x**2
#       5 res = parallelise(fn, inputs=[("a", 1), ("b", 2)])
# ----> 7 print(dict(res))
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/futures/_base.py:639, in Executor.map.<locals>.result_iterator()
#     637 # Careful not to keep a reference to the popped future
#     638 if timeout is None:
# --> 639     yield _result_or_cancel(fs.pop())
#     640 else:
#     641     yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/futures/_base.py:311, in _result_or_cancel(***failed resolving arguments***)
#     309 try:
#     310     try:
# --> 311         return fut.result(timeout)
#     312     finally:
#     313         fut.cancel()
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File ~/git/mxlpy/src/mxlpy/parallel.py:57, in _wrap_ip_call(fn, el_ip)
#      52 def _wrap_ip_call[Tin, Tout](
#      53     fn: Callable[[Tin], Tout],
#      54     el_ip: tuple[Tin, Executor],
#      55 ) -> Tout:
#      56     el, ip = el_ip
# ---> 57     return ip.call(fn, el)
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/interpreters/__init__.py:233, in Interpreter.call(self, callable, *args, **kwargs)
#     220 def call(self, callable, /, *args, **kwargs):
#     221     """Call the object in the interpreter with given args/kwargs.
#     222
#     223     Nearly all callables, args, kwargs, and return values are
#    (...)    231     happens with Interpreter.exec().
#     232     """
# --> 233     return self._call(callable, args, kwargs)
#
# File ~/git/mxlpy/.pixi/envs/default/lib/python3.14/concurrent/interpreters/__init__.py:215, in Interpreter._call(self, callable, args, kwargs)
#     214 def _call(self, callable, args, kwargs):
# --> 215     res, excinfo = _interpreters.call(self._id, callable, args, kwargs, restrict=True)
#     216     if excinfo is not None:
#     217         raise ExecutionFailed(excinfo)
#
# NotShareableError: func not shareable

# %% [markdown]
# ## Restricting cores
#
# By default `parallelise` will use all available CPU cores.
# In case you want to limit that, you can use the `max_workers` parameter to set an explicit number.

# %%
res = parallelise(
    fn,
    inputs=[("a", 1), ("b", 2)],
    max_workers=2,
)

print(dict(res))

# %% [markdown]
# ## Caching results
#
# By supplying the `Cache` class, you can automatically save and retrieve your calculated values.
#
# The default settings are
#
# - Write results into `.cache` folder
# - Write and load a `pickle` file, using `{key}.p` of `inputs` as the name

# %%
res = parallelise(
    fn,
    inputs=[("a", 1), ("b", 2)],
    cache=Cache(),
)

print(dict(res))

# %% [markdown]
# You can overrwite all of this.
# Shown here is how you set a custom temporary directory

# %%
res = parallelise(
    fn,
    inputs=[("a", 1), ("b", 2)],
    cache=Cache(
        tmp_dir=Path(".cache"),
    ),
)

print(dict(res))

# %% [markdown]
# And shown here is how you can implement custom load and save functions.
#
# **Be careful to always update both `load_fn` and `save_fn` if you change one of them**

# %%
def name_fn(k: Hashable) -> str:
    return f"{k}.p"


def load_fn(file: Path) -> Any:
    with file.open("rb") as fp:
        return pickle.load(fp)  # nosec


def save_fn(file: Path, data: Any) -> None:
    with file.open("wb") as fp:
        pickle.dump(data, fp)


res = parallelise(
    fn,
    inputs=[("a", 1), ("b", 2)],
    cache=Cache(
        name_fn=name_fn,
        load_fn=load_fn,
        save_fn=save_fn,
    ),
)

print(dict(res))

# %% [markdown]
# ## Timeouts
#
# You can set a timeout for long-running functions.
# This timeout runs **per function call**, so you can recover all other runs without any problems.
#
# E.g. check below how `a` is retrieved, while `b` caused a timeout and is thus missing.

# %%
import time


def delay_for_seconds(t: int) -> int:
    time.sleep(t)
    return t


res = parallelise(
    delay_for_seconds,
    inputs=[("a", 1), ("b", 2)],
    timeout=1,
)
res

# %% [markdown]
# ## Progress bar customisation
#
# We use [tqdm](https://pypi.org/project/tqdm/) as our progress bar.
#
# You can disable it using the `disable_tqdm` flag

# %%
res = parallelise(
    fn,
    inputs=[("a", 1), ("b", 2)],
    disable_tqdm=True,
)
res

# %% [markdown]
# and customise the loop descriptor using `tqdm_desc`

# %%
res = parallelise(
    fn,
    inputs=[("a", 1), ("b", 2)],
    tqdm_desc="Loop name",
)
res

# %% [markdown]
# ## Running sequentially
#
# You can run a function sequentially using `parallel=False`.
# While it might seems odd in the beginning to do this, the point is easy refactoring in cases where you might *nest* analyses.
#
# You generally don't want `n` processes to spawn `n` new processes each.
# The `parallel=False` flag allows you to re-use analyses written using `parallel=True` with only a single change.
#
# This can also occasionally be useful for de-bugging functions running in parallel

# %%
def other_fn(x: int) -> dict[str, int]:
    res = parallelise(
        fn,
        inputs=[("a1", x), ("b1", x**2)],
        parallel=False,  # this shouldn't be set to True!
    )
    return dict(res)


res = parallelise(
    other_fn,
    inputs=[("x1", 2), ("x2", 3)],
    parallel=True,
)
res
